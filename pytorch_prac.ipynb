# %% [markdown]
# <a href="https://colab.research.google.com/github/SharveshC/CodeFlow/blob/main/pytorch_prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy
import pandas
import matplotlib.pyplot as plt
print(torch.__version__)
print(numpy.__version__)
print(pandas.__version__)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1987/751790109.py in <cell line: 0>()
# ----> 1 import torch
#       2 import numpy
#       3 import pandas
#       4 import matplotlib.pyplot as plt
#       5 print(torch.__version__)
#
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py in <module>
#    2783
#    2784 if not TYPE_CHECKING:
# -> 2785     from torch import _meta_registrations
#    2786
#    2787 # Enable CUDA Sanitizer
#
# /usr/local/lib/python3.12/dist-packages/torch/_meta_registrations.py in <module>
#      10 import torch._prims_common as utils
#      11 from torch import SymBool, SymFloat, Tensor
# ---> 12 from torch._decomp import (
#      13     _add_op_to_registry,
#      14     _convert_out_params,
#
# /usr/local/lib/python3.12/dist-packages/torch/_decomp/__init__.py in <module>
#     275
#     276 # populate the table
# ...

# %%
## introduction to tensors:
## creating a tenors:
#scalar:
scalar = torch.tensor(7)
scalar

# %%
scalar.ndim

# %%
scalar.item()

# %%
#vector:
vector = torch.tensor([7,7])
vector

# %%
vector.ndim

# %%
vector.shape

# %%
matrix=torch.tensor([[1,2,3],[4,5,6]])
print(matrix.dim())

# %%
print(matrix.shape)

# %%
#Tensors
Tensor=torch.tensor([[[1,2,3],[3,6,9],[2,4,5]]])
Tensor

# %%
Tensor.ndim

# %%
Tensor.shape

# %% [markdown]
# shape -
#
# dim -

# %% [markdown]
# ### Random tensors

# %% [markdown]
# random tensors - to be filled with rand numbers

# %%
random_tensor=torch.rand(2,3)

# %%
print(random_tensor)

# %%
random_tensor.ndim

# %% [markdown]
# ### Empty Tensors

# %%
empty_tensors=torch.empty(2,4)

# %%
print(empty_tensors)
